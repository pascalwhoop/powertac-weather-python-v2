# %%
TARGETS = [
    0.5161290323,
    0.7188940092,
    0.8698156682,
    0.9631336406,
    1.0529953917,
    1.133640553,
    1.1993087558,
    1.2523041475,
    1.3214285714,
    1.3536866359,
    1.3859447005,
    1.418202765,
    1.4550691244,
    1.4919354839,
    1.5080645161,
    1.5241935484,
    1.5403225806,
    1.5564516129,
    1.5771889401,
    1.5887096774,
    1.599078341,
    1.6094470046,
    1.6152073733,
    1.6221198157
]

DELTAS = [
    0.5161445829244465,
    0.4997949220914800,
    0.4888900890981265,
    0.4130704994139208,
    0.4253848976635191,
    0.4184687781309460,
    0.3936649202161004,
    0.3588710293244263,
    0.4231553114393557,
    0.2889082972475748,
    0.1702626162506641,
    0.1689796096722179,
    0.1883929096181789,
    0.18962579311684136,
    0.1305896052644996,
    0.11633757757456899,
    0.12243322493106974,
    0.12050860605514514,
    0.12994755220882373,
    0.08640391531140598,
    0.09885577242432499,
    0.10596546947835507,
    0.10847755148571396,
    0.0638920547195091
]

DELTAS_used = [
    0.5162049085865681,
    0.5001617542505696,
    0.4895374321040051,
    0.4133156231642960,
    0.4254929262239113,
    0.4185106291938654,
    0.3936224626324226,
    0.3592021873751825,
    0.4227455362185202,
    0.2889786621257507,
    0.2990803149973352,
    0.2980053411248858,
    0.3278548743792022,
    0.3268537591678519,
    0.2222389153440853,
    0.2147271278862675,
    0.2271812561709724,
    0.2188789204055356,
    0.2534842863405704,
    0.1943563797606358,
    0.1769833979598591,
    0.1811455527733305,
    0.1341968742628301,
    0.1580705552864369,
]

# %%
import matplotlib as plot
import numpy

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

y1 = TARGETS
y2 = DELTAS
y3 = DELTAS_used
x = np.arange(24)

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(x,y1, 'o')
ax.plot(x,y2, 'o')
ax.plot(x,y3, 'o')
ax.set_title('Distribution of TARGETS (blue) and DELTAS (orange), DELTAS_used (green)')
plt.show()

# %% [markdown]
# # plotting their tau

# %%
import random
forecasts = []

for _ in range(1):
        tau = 0
        temp = []
        for i in range(24):
            tau = tau + random.gauss(0, DELTAS[i])
            temp.append(tau)
        forecasts.append(temp)

# %%
np_fc = np.array(forecasts)

# %% [markdown]
# ## Generating forecasts in python
#
# Let's look at the generated forecasts in python

# %%
import forecast_generator as fg
import weather_data_extractor as we

#import weather_py.forecast_generator as fg

# %%
data_packets = we.download_files(we.weather_file_urls)
all_data = []
for p in data_packets:
    d = we.convert_weather_file(p)
    all_data.extend(d)
    
len(all_data)
# Out:
# ['/tmp/tmprmsgi42z', '..']  ..
# ['/tmp/tmpoljjh3b2', '..']  ..
# 26280

# %% [markdown]
# Okay, we got all the data in our `all_data` object. This was the "download and import" part of the previous scripts. Next we need to create our forecasts. But first, let's look at the data for a sec

# %%
all_data[0:5]
# Out:
# [[datetime.datetime(2009, 1, 1, 0, 0), 'rotterdam', -1.5, 1.0, 240, 1.0],
#  [datetime.datetime(2009, 1, 1, 1, 0), 'rotterdam', -1.2, 1.0, 270, 1.0],
#  [datetime.datetime(2009, 1, 1, 2, 0), 'rotterdam', -1.1, 2.0, 240, 1.0],
#  [datetime.datetime(2009, 1, 1, 3, 0), 'rotterdam', -1.0, 1.0, 250, 1.0],
#  [datetime.datetime(2009, 1, 1, 4, 0), 'rotterdam', -0.9, 1.0, 250, 1.0]]

# %%
forecasts = fg.make_forecasts(np.array(all_data[0:1000]))

# %%
forecasts[0]
# Out:
# array([list([datetime.datetime(2009, 1, 1, 1, 0), 'rotterdam', -3.067585708096725, 0.8049662666366935, 269.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 2, 0), 'rotterdam', -5.213381526465872, 1.3590362195206978, 237.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 3, 0), 'rotterdam', -6.0521618778515345, 0.9450087612308385, 246.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 4, 0), 'rotterdam', -6.070089497570391, 1.5642171903931752, 245.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 5, 0), 'rotterdam', -7.386346914231759, 1.8635888197631387, 248.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 6, 0), 'rotterdam', -8.304361385484992, 1.4721768119198808, 310.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 7, 0), 'rotterdam', -8.203512276060318, 1.4572002327095586, 311.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 8, 0), 'rotterdam', -7.6157253524823405, 2.2835881516847225, 184.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 9, 0), 'rotterdam', -7.431147438144302, 2.192394675527309, 209.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 10, 0), 'rotterdam', -7.264104304675136, 1.6497780019220019, 262.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 11, 0), 'rotterdam', -7.985386864671022, 1.819734398188298, 262.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 12, 0), 'rotterdam', -7.6302778590044245, 1.9758007775287194, 242.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 13, 0), 'rotterdam', -7.537048775642487, 0.6216923524058162, 309.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 14, 0), 'rotterdam', -6.88258887050405, 0.5582778658006557, 229.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 15, 0), 'rotterdam', -6.668628755382932, 1.7323843603921505, 250.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 16, 0), 'rotterdam', -6.987654522386082, 0.9350909895195972, 253.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 17, 0), 'rotterdam', -6.913276424763251, 1.5590703589542345, 221.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 18, 0), 'rotterdam', -6.913497997031761, 0.5877161676855382, 234.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 19, 0), 'rotterdam', -6.581266339831859, 1.6806108457996745, 211.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 20, 0), 'rotterdam', -6.400798037656999, 1.4576838784269939, 222.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 21, 0), 'rotterdam', -6.531494787312559, 3.6219378130555437, 233.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 22, 0), 'rotterdam', -6.25551141532935, 1.580868164634372, 222.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 1, 23, 0), 'rotterdam', -6.057023860508522, 1.4391185271465028, 261.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)]),
#        list([datetime.datetime(2009, 1, 2, 0, 0), 'rotterdam', -5.551370303432186, 1.5693542431125342, 253.0, 1.0, datetime.datetime(2009, 1, 1, 0, 0)])],
#       dtype=object)

# %%
x = range(24)
import sklearn.preprocessing as skpp

#let's look at 10 forecasting instances
for i in range(10):
    fig, ax = plt.subplots()
    fc_instance = forecasts[i]
    
    ys = []
    for j in range(2,6):
        y = [n[:][j] for n in fc_instance]
        ys.append(y)
        
    ys = skpp.normalize(ys)
    ax.plot(x, ys[0], '-', label='temp')
    ax.plot(x, ys[1], '-', label='speed')
    ax.plot(x, ys[2], '-', label='direction')
    ax.plot(x, ys[3], '-', label='CCover')
    fig.legend()
    plt.show()

# %% [markdown]
# ## Verifying generated forecasts
#
# To verify the forecasts, I can visually use something **like this**
#
# ![img](https://i.imgur.com/OLPY0cS.png)

# %%
#reimporting libraries as they are being changed
import importlib
importlib.reload(fg)
importlib.reload(we)

np.random.seed(167) #fixing for replicability
forecast_length = 24
base_data = np.array(all_data)[650:650+forecast_length+1]
simulations = 500
results = []
for i in range(simulations):
    results.append(fg.make_24h_forecasts(base_data))



for _type in range(2,6):
    # results is list of list of lists
    type_results = [item[:,_type] for item in np.array(results)]
    
    #plotting the simulations (1000 x 24) --> 24k points. 
    fig, ax = plt.subplots()
    x = range(forecast_length)
    #plotting our "true data"
    ax.plot(x,base_data[:-1,_type], '-')

    #plotting our simulated data "cloud"
    for result in type_results:
        ax.scatter(x,result, c='orange', s=3, alpha=0.02 )
    ax.set_title("Type number " + str(_type))
    plt.show()

# %%
import tests.test_performance as wp
import unittest

tester = wp.TestPerformance()
result = tester._test_simulation_generation_perf()
# Out:
# Testing performance for creating 60000 forecasts based on 2500 weather_points
# The test is run 7 times and then the best result is taken
# 0.7958468949946109
